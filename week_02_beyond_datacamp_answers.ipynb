# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/startakovsky/epib-463-fall-2022/blob/main/week_02_beyond_datacamp_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %% [markdown]
# # Python Beyond Datacamp

# %% [markdown]
# Welcome to your first Google Colab working session. In this notebook, we will work with one other person in a breakout room. *All answers are in code, no text cells unless you want to.*

# %% [markdown]
# ## 1. Python Basics

# %% [markdown]
# **Exercise**: Determine what Python version you're running.

# %% [markdown]
# **Exercise**: Sort this list of names in alphabetical order, set the result to a list named `sorted_names`.

# %%
names = [
    'Rabia', 'Kyrone', 'Michael', 
    'Max', 'Hillary', 'Nancy', 
    'Alexander', 'Jalen', 'Ruth', 
    'Emily', 'Kyle', 'Chuk', 'Noela', 
    'Olivia', 'Bella', 'Jacob', 
    'Abenezer', 'Sonia', 'Janet', 
    'Kristen', 'Kelsey', 'Mitch', 
    'Alan', 'Zack'
]

# %%
# sorted_names =

# %% [markdown]
# **Exercise**: Create a new variable named `sorted_names_abridged` which contains only the first 5 names alphabetically.

# %% [markdown]
# **Exercise**: Create a function named `get_first_n_names` that takes an _argument_ `num_names` and returns the first `num_names` number of names, alphabetically.

# %% [markdown]
# **Exercise**: Use `get_first_n_names` to test different numbers for `num_names`.

# %% [markdown]
# ## 2. A medium hard problem
#
# > I spoke about this at the end of class on Monday. Imagine you want to determine all of the possible ways to separate everyone into breakout rooms of two people. Write some code to try to make headway on this problem.

# %% [markdown]
# **Pre-Exercise**: Generate a list of tuples, where each tuple is of length 1, containing every name from the above list.

# %% [markdown]
# **Exercise**: Generate a list of tuples, where each tuple is of length 2, containing two names from the above list. We want to put every single possible pair, without duplicates, in this list.

# %% [markdown]
# **Exercise**: Try to do the same as the previous exercise but this time read the [itertools page](https://docs.python.org/3/library/itertools.html) (hint: are these permutations?).

# %% [markdown]
# **Exercise**: Hopefully the previous two answers gave the same answer. Do a spot check and see if the number of pairs generated by your answer and the answer given by using the appropriate `itertools` function are the same.

# %% [markdown]
# ## 3. Random Module and Counting

# %% [markdown]
# **Exercise**: Read about the `random` module [here](https://docs.python.org/3.7/library/random.html) and skim the page to read about random choice . . .

# %% [markdown]
# **Exercise**: Use the `random` module to randomly choose one of the first five names, alphabetically.

# %% [markdown]
# **Exercise**: Now use the random module to randomly generate a list `named list_of_random_duplicates` of length a hundred thousand.

# %% [markdown]
# **Exercise**: Generate a `dict` named `name_counts` where the _keys_ are the names and the _values_ are the number of times the name appears in the list.

# %% [markdown]
# **Exercise**: Now go and read about [Counters](https://docs.python.org/3/library/collections.html#collections.Counter)
